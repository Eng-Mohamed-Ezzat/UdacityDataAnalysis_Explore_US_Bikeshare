# %%
import time
import pandas as pd
import numpy as np
import calendar as cl

# %%
DATA_CITY = { 'All' : 'all',
              'Chicago': 'chicago.csv',
              'New york': 'new_york_city.csv',
              'Washington': 'washington.csv' }

DATA_Month = {
    0: 'All', 
    1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun',
    7:'Jul', 8:'Aug', 9:'Sep', 10:'Oct', 11:'Nov', 12:'Dec'}

DATA_Day = ['All'] + [d[0:3] for d in cl.day_name]

# %%
def get_filters():
    """
    Asks user to specify a city, month, and day to analyze.

    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    print('Hello! Let\'s explore some US bikeshare data!')
    
    # get user input for city (chicago, new york city, washington). HINT: Use a while loop to handle invalid inputs
    
    
    while True:
        msg = "Choose city:\n" \
        "[0]: All\n" \
        "[1]: Chicago\n" \
        "[2]: New York\n" \
        "[3]: Washington\n" \
        "Please type city name or number:"
        usrcity = "1" #input(msg)

        if usrcity.isnumeric() and int(usrcity) in range(len(DATA_CITY)) or usrcity.title() in DATA_CITY.keys():
            city = list(DATA_CITY.keys())[int(usrcity)] if usrcity.isnumeric() else usrcity.title() 
            break
        else:
            print("Wrong city Entry. :(")
        
        break #Remove this
    
    msg = "- You are choose {} {}.".format(city.title() if city.lower()!="all" else city.lower(),"city" if city.lower()!="all" else "cities")
    print(msg)
    
    # get user input for month (all, january, february, ... , june)

    while True:
        msg = "Choose month:\n" \
        "[0]: All\n" \
        "[?]: Month Number\n" \
        "Please type month name or number:"
        usrmonth = "1" #input(msg)

        if usrmonth.isnumeric() and int(usrmonth) in range(len(DATA_Month)) or usrmonth[:3].title() in DATA_Month.values():
            month = list(DATA_Month.values())[int(usrmonth)] if usrmonth.isnumeric() else usrmonth[:3].title() 
            break
        else:
            print("Wrong month Entry. :(")
        
        break #Remove this

    msg = "- You are choose {} {}.".format(month.lower(),"month" if month.lower() !="all" else "available monthes")
    print(msg)

    # get user input for day of week (all, monday, tuesday, ... sunday)

    while True:
        msg = "Choose day:\n" \
        "[0]: All\n" \
        "[?]: Day Name\n" \
        "Please type week day name or number:"
        usrday = "1" #input(msg)

        if usrday.isnumeric() and int(usrday) in range(len(DATA_Day)) or usrday[:3].title() in DATA_Day:
            day = DATA_Day[int(usrday)] if usrday.isnumeric() else usrday[:3].title() 
            break
        else:
            print("Wrong day Entry. :(")
        
        break #Remove this

    msg = "- You are choose {}{}.".format(day.lower(),"day" if day.lower()!="all" else " available days")
    print(msg)

    
    print('-'*40)
    
    return city, month, day

# %%
city, month, day = 'Chicago', 'Jan', 'Mon'
print(city, month, day)
# Out:
# Chicago Jan Mon

# %%
df = pd.read_csv("{}".format(DATA_CITY[city]),parse_dates=['Start Time','End Time'])
print(df.head())
# Out:
#    Unnamed: 0          Start Time            End Time  Trip Duration  \
# 0     1423854 2017-06-23 15:09:32 2017-06-23 15:14:53            321
# 1      955915 2017-05-25 18:19:03 2017-05-25 18:45:53           1610
# 2        9031 2017-01-04 08:27:49 2017-01-04 08:34:45            416
# 3      304487 2017-03-06 13:49:38 2017-03-06 13:55:28            350
# 4       45207 2017-01-17 14:53:07 2017-01-17 15:02:01            534
#
#                    Start Station                   End Station   User Type  \
# 0           Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber
# 1            Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber
# 2             May St & Taylor St           Wood St & Taylor St  Subscriber
# 3  Christiana Ave & Lawrence Ave  St. Louis Ave & Balmoral Ave  Subscriber
# 4         Clark St & Randolph St  Desplaines St & Jackson Blvd  Subscriber
#
#    Gender  Birth Year
# 0    Male      1992.0
# 1  Female      1992.0
# 2    Male      1981.0
# 3    Male      1986.0
# 4    Male      1975.0

# %%
df['Trip Duration'].describe()
# Out:
# count    300000.000000
# mean        936.239290
# std        1548.792767
# min          60.000000
# 25%         393.000000
# 50%         670.000000
# 75%        1125.000000
# max       86224.000000
# Name: Trip Duration, dtype: float64

# %%
df['Trip Duration'].describe().max()
# Out:
# 300000.0

# %%
df.groupby(['Gender'])['Trip Duration'].mean()
# Out:
# Gender
# Female    781.515946
# Male      673.211750
# Name: Trip Duration, dtype: float64

# %%
"Gender" in df
# Out:
# True

# %%
df.head()
# Out:
#    Unnamed: 0          Start Time            End Time  Trip Duration  \
# 0     1423854 2017-06-23 15:09:32 2017-06-23 15:14:53            321
# 1      955915 2017-05-25 18:19:03 2017-05-25 18:45:53           1610
# 2        9031 2017-01-04 08:27:49 2017-01-04 08:34:45            416
# 3      304487 2017-03-06 13:49:38 2017-03-06 13:55:28            350
# 4       45207 2017-01-17 14:53:07 2017-01-17 15:02:01            534
#
#                    Start Station                   End Station   User Type  \
# 0           Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber
# 1            Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber
# 2             May St & Taylor St           Wood St & Taylor St  Subscriber
# 3  Christiana Ave & Lawrence Ave  St. Louis Ave & Balmoral Ave  Subscriber
# 4         Clark St & Randolph St  Desplaines St & Jackson Blvd  Subscriber
#
#    Gender  Birth Year
# 0    Male      1992.0
# 1  Female      1992.0
# 2    Male      1981.0
# 3    Male      1986.0
# 4    Male      1975.0

# %%
df['Month'] = [m[0:3] for m in df['Start Time'].dt.month_name()]
df['Day'] = [d[0:3] for d in df['Start Time'].dt.day_name()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     300000 non-null  int64
#  1   Start Time     300000 non-null  datetime64[ns]
#  2   End Time       300000 non-null  datetime64[ns]
#  3   Trip Duration  300000 non-null  int64
#  4   Start Station  300000 non-null  object
#  5   End Station    300000 non-null  object
#  6   User Type      300000 non-null  object
#  7   Gender         238948 non-null  object
#  8   Birth Year     238981 non-null  float64
#  9   Month          300000 non-null  object
#  10  Day            300000 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(6)
# memory usage: 25.2+ MB

# %%
#df[df['Day'] == 'Fri' & df['Month'] == 'Jun']
df[(df.Day == "Fri") & (df.Month == "Jun")]
# Out:
#         Unnamed: 0          Start Time            End Time  Trip Duration  \
# 0          1423854 2017-06-23 15:09:32 2017-06-23 15:14:53            321
# 21         1420915 2017-06-23 12:21:01 2017-06-23 12:32:54            713
# 27         1186035 2017-06-09 07:48:55 2017-06-09 07:52:30            215
# 31         1539334 2017-06-30 10:56:50 2017-06-30 11:40:20           2610
# 33         1187843 2017-06-09 09:08:19 2017-06-09 09:15:09            410
# ...            ...                 ...                 ...            ...
# 299834     1067394 2017-06-02 11:03:39 2017-06-02 11:17:51            852
# 299835     1535028 2017-06-30 05:51:35 2017-06-30 06:06:44            909
# 299882     1199218 2017-06-09 18:32:26 2017-06-09 18:36:54            268
# 299906     1418526 2017-06-23 08:56:40 2017-06-23 09:00:35            235
# 299947     1315604 2017-06-16 22:02:38 2017-06-16 22:17:00            862
#
#                      Start Station                           End Station  \
# 0             Wood St & Hubbard St               Damen Ave & Chicago Ave
# 21              Rush St & Cedar St                Halsted St & Willow St
# 27           Canal St & Madison St                Clark St & Randolph St
# 31                 McCormick Place                     Adler Planetarium
# 33      Halsted St & Diversey Pkwy          Sheffield Ave & Waveland Ave
# ...                            ...                                   ...
# 299834     Hermitage Ave & Polk St                     900 W Harrison St
# 299835        Clinton St & Lake St                 Wolcott Ave & Polk St
# 299882     Clinton St & Madison St                  Clinton St & Lake St
# 299906    Loomis St & Lexington St                 Wolcott Ave & Polk St
# 299947     Franklin St & Monroe St  Orleans St & Chestnut St (NEXT Apts)
#
#          User Type  Gender  Birth Year Month  Day  Start Hour  \
# 0       Subscriber    Male      1992.0   Jun  Fri          15
# 21      Subscriber    Male      1985.0   Jun  Fri          12
# 27      Subscriber    Male      1974.0   Jun  Fri           7
# 31        Customer     NaN         NaN   Jun  Fri          10
# 33      Subscriber    Male      1984.0   Jun  Fri           9
# ...            ...     ...         ...   ...  ...         ...
# 299834  Subscriber    Male      1971.0   Jun  Fri          11
# 299835  Subscriber    Male      1985.0   Jun  Fri           5
# 299882  Subscriber    Male      1991.0   Jun  Fri          18
# 299906  Subscriber  Female      1992.0   Jun  Fri           8
# 299947    Customer     NaN         NaN   Jun  Fri          22
#
#                                              Trip from to
# 0         Wood St & Hubbard St to Damen Ave & Chicago Ave
# 21           Rush St & Cedar St to Halsted St & Willow St
# 27        Canal St & Madison St to Clark St & Randolph St
# 31                   McCormick Place to Adler Planetarium
# 33      Halsted St & Diversey Pkwy to Sheffield Ave & ...
# ...                                                   ...
# 299834       Hermitage Ave & Polk St to 900 W Harrison St
# 299835      Clinton St & Lake St to Wolcott Ave & Polk St
# 299882    Clinton St & Madison St to Clinton St & Lake St
# 299906  Loomis St & Lexington St to Wolcott Ave & Polk St
# 299947  Franklin St & Monroe St to Orleans St & Chestn...
#
# [16744 rows x 13 columns]

# %%
test = df(lambda x: x.str.contains(';').any())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-f105d1de9b0e> in <module>
# ----> 1 test = df(lambda x: x.str.contains(';').any())
#
# TypeError: 'DataFrame' object is not callable

# %%
df.filter(like='1', axis=0)
# Out:
#         Unnamed: 0          Start Time            End Time  Trip Duration  \
# 1           955915 2017-05-25 18:19:03 2017-05-25 18:45:53           1610
# 10          175805 2017-02-15 07:09:55 2017-02-15 07:14:56            301
# 11           71678 2017-01-22 15:15:45 2017-01-22 15:31:02            917
# 12           19061 2017-01-08 16:03:00 2017-01-08 16:07:37            277
# 13         1023296 2017-05-30 15:46:18 2017-05-30 15:52:12            354
# ...            ...                 ...                 ...            ...
# 299951      796790 2017-05-12 08:43:48 2017-05-12 08:53:28            580
# 299961      953555 2017-05-25 16:58:41 2017-05-25 17:12:39            838
# 299971      852513 2017-05-16 09:18:52 2017-05-16 09:38:02           1150
# 299981     1212375 2017-06-10 14:52:58 2017-06-10 15:29:52           2214
# 299991      723217 2017-05-03 19:15:23 2017-05-03 19:29:32            849
#
#                          Start Station                   End Station  \
# 1                  Theater on the Lake  Sheffield Ave & Waveland Ave
# 10                Broadway & Barry Ave      Wilton Ave & Belmont Ave
# 11      Southport Ave & Wellington Ave        Clark St & Schiller St
# 12               Green St & Madison St      Ada St & Washington Blvd
# 13          Larrabee St & Kingsbury St             Clark St & Elm St
# ...                                ...                           ...
# 299951        Kingsbury St & Kinzie St           Canal St & Adams St
# 299961            Orleans St & Ohio St     Sedgwick St & Webster Ave
# 299971                  Dusable Harbor           Theater on the Lake
# 299981      Franklin St & Jackson Blvd    Lake Shore Dr & North Blvd
# 299991    Milwaukee Ave & Wabansia Ave     Ashland Ave & Chicago Ave
#
#          User Type  Gender  Birth Year Month  Day  Start Hour  \
# 1       Subscriber  Female      1992.0   May  Thu          18
# 10      Subscriber  Female      1993.0   Feb  Wed           7
# 11      Subscriber    Male      1964.0   Jan  Sun          15
# 12      Subscriber    Male      1961.0   Jan  Sun          16
# 13      Subscriber    Male      1985.0   May  Tue          15
# ...            ...     ...         ...   ...  ...         ...
# 299951  Subscriber  Female      1982.0   May  Fri           8
# 299961  Subscriber    Male      1991.0   May  Thu          16
# 299971  Subscriber    Male      1976.0   May  Tue           9
# 299981    Customer     NaN         NaN   Jun  Sat          14
# 299991  Subscriber  Female      1982.0   May  Wed          19
#
#                                              Trip from to
# 1       Theater on the Lake to Sheffield Ave & Wavelan...
# 10       Broadway & Barry Ave to Wilton Ave & Belmont Ave
# 11      Southport Ave & Wellington Ave to Clark St & S...
# 12      Green St & Madison St to Ada St & Washington Blvd
# 13        Larrabee St & Kingsbury St to Clark St & Elm St
# ...                                                   ...
# 299951    Kingsbury St & Kinzie St to Canal St & Adams St
# 299961  Orleans St & Ohio St to Sedgwick St & Webster Ave
# 299971              Dusable Harbor to Theater on the Lake
# 299981  Franklin St & Jackson Blvd to Lake Shore Dr & ...
# 299991  Milwaukee Ave & Wabansia Ave to Ashland Ave & ...
#
# [181902 rows x 13 columns]

# %%
day = 'Fri'
month = 'May'

# %%
df[(df.Day == (df.Day if day== 'All' else day)) & (df.Month == (df.Month if month=="All" else month))]
# Out:
#         Unnamed: 0          Start Time            End Time  Trip Duration  \
# 6           961916 2017-05-26 09:41:44 2017-05-26 09:46:25            281
# 53          959864 2017-05-26 07:31:20 2017-05-26 07:38:57            457
# 66          739835 2017-05-05 17:49:23 2017-05-05 18:00:34            671
# 77          959137 2017-05-26 06:04:08 2017-05-26 06:08:21            253
# 115         803235 2017-05-12 16:52:32 2017-05-12 17:05:50            798
# ...            ...                 ...                 ...            ...
# 299900      962603 2017-05-26 11:05:29 2017-05-26 11:10:29            300
# 299931      960238 2017-05-26 07:53:35 2017-05-26 08:00:54            439
# 299949      735407 2017-05-05 09:16:21 2017-05-05 09:22:53            392
# 299951      796790 2017-05-12 08:43:48 2017-05-12 08:53:28            580
# 299962      799738 2017-05-12 13:19:53 2017-05-12 13:24:19            266
#
#                        Start Station               End Station   User Type  \
# 6              Ashland Ave & Lake St      Wood St & Hubbard St  Subscriber
# 53      Clinton St & Washington Blvd      State St & Kinzie St  Subscriber
# 66              Clinton St & Lake St      Ogden Ave & Race Ave  Subscriber
# 77      Financial Pl & Congress Pkwy  Canal St & Monroe St (*)  Subscriber
# 115            Franklin St & Lake St  Wells St & Evergreen Ave  Subscriber
# ...                              ...                       ...         ...
# 299900     Wabash Ave & Roosevelt Rd    State St & Harrison St  Subscriber
# 299931     Columbus Dr & Randolph St   Franklin St & Quincy St  Subscriber
# 299949          Orleans St & Ohio St   Franklin St & Monroe St  Subscriber
# 299951      Kingsbury St & Kinzie St       Canal St & Adams St  Subscriber
# 299962    LaSalle St & Washington St     Canal St & Madison St  Subscriber
#
#         Gender  Birth Year Month  Day  Start Hour
# 6       Female      1983.0   May  Fri           9
# 53      Female      1967.0   May  Fri           7
# 66        Male      1991.0   May  Fri          17
# 77        Male      1963.0   May  Fri           6
# 115       Male      1991.0   May  Fri          16
# ...        ...         ...   ...  ...         ...
# 299900    Male      1962.0   May  Fri          11
# 299931    Male      1980.0   May  Fri           7
# 299949    Male      1990.0   May  Fri           9
# 299951  Female      1982.0   May  Fri           8
# 299962    Male      1990.0   May  Fri          13
#
# [7090 rows x 12 columns]

# %%
df['Month'].mode()[0]
# Out:
# 'Jun'

# %%
df['Start Hour'] = df['Start Time'].dt.hour

# %%
df['Trip from to'] = df['Start Station'] +" to " + df['End Station']

# %%
df['Trip Duration'].mean()
# Out:
# 936.23929

# %%
print(df.groupby(['User Type'])['User Type'].count())
# Out:
# [61110, 1, 238889]

# %%
myGroups = df.groupby(['User Type'])['User Type'].groups

# %%
for k in myGroups:
    print(k, ":",len(myGroups[k]))
# Out:
# Customer : 61110
# Dependent : 1
# Subscriber : 238889

# %%
df['Birth Year'].describe()
# Out:
# count    238981.000000
# mean       1980.858223
# std          11.003329
# min        1899.000000
# 25%        1975.000000
# 50%        1984.000000
# 75%        1989.000000
# max        2016.000000
# Name: Birth Year, dtype: float64

# %%
df['Birth Year'].max()
# Out:
# 2016.0

# %%
df["Birth Year"] = df["Birth Year"].astype(str).astype(int) 
print("The earliest is {}, most recent is {}, and most common year of birth is {}.".format(df['Birth Year'].max(),df['Birth Year'][0],df['Birth Year'].mode()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-d271611a25ca> in <module>
# ----> 1 df["Birth Year"] = df["Birth Year"].astype(str).astype(int)
#       2 print("The earliest is {}, most recent is {}, and most common year of birth is {}.".format(df['Birth Year'].max(),df['Birth Year'][0],df['Birth Year'].mode()))
#       3
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     593             vals1d = values.ravel()
#     594             try:
# --> 595                 values = astype_nansafe(vals1d, dtype, copy=True)
#     596             except (ValueError, TypeError):
#     597                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     970         # work around NumPy brokenness, #1987
#     971         if np.issubdtype(dtype.type, np.integer):
# --> 972             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     973
#     974         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '1992.0'

# %%
cl.month_name
